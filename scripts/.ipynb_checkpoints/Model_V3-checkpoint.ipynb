# %%
import wave
import glob
import random

# for data, model, training
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import models
from scipy import signal

import librosa
import librosa.display

# for visuals and statistics
import matplotlib.pyplot as plt
import seaborn as sns

# Set the seed value for experiment reproducibility.
seed = 42
random.seed(42)
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
def get_and_shuffle_filenames(dir_name):
    filenames = glob.glob(str(data_dir) + "/*")
    random.shuffle(filenames)
    return filenames

data_dir = "../recordings"
filenames = get_and_shuffle_filenames(data_dir)

print(filenames[:5])
# Out:
# ['../recordings/2_jackson_13.wav', '../recordings/6_george_34.wav', '../recordings/7_george_5.wav', '../recordings/1_yweweler_21.wav', '../recordings/2_george_42.wav']

# %%
# https://www.tensorflow.org/tutorials/audio/simple_audio

def decode_audio(file_path):
    # read file to get buffer                                                                                               
    ifile = wave.open(file_path)
    samples = ifile.getnframes()
    audio = ifile.readframes(samples)

    # convert buffer to float32 using NumPy                                                                                 
    audio_as_np_int16 = np.frombuffer(audio, dtype=np.int16)
    audio_as_np_float32 = audio_as_np_int16.astype(np.float32)
    
    # get largest absolute value
    max_val = np.max(
        np.absolute(
            [np.max(audio_as_np_float32), np.min(audio_as_np_float32)]))
    audio_normalized = audio_as_np_float32 / max_val

    return audio_normalized

def get_label(file_path):
    # label is in the filename
    parts = file_path.split("/")
    label = int(parts[2].split("_")[0])

    return label

# %%
# to remove outliers 
X_unfiltered = [(file_path, decode_audio(file_path)) for file_path in filenames]
X_lengths = [audio.shape[0] for _, audio in X_unfiltered]

max_length = int(np.mean(X_lengths) + 2 * np.std(X_lengths))
print(np.mean(X_lengths))
print(np.std(X_lengths))
print(max_length)
# Out:
# 3499.4746666666665
# 1180.9471707171701
# 5861

# %%
def mel_spec(signal):
    mel_spect = librosa.feature.melspectrogram(y=signal, sr=8000, n_fft=248, hop_length=248)
    mel_spect = librosa.power_to_db(mel_spect, ref=np.max)
    return mel_spect

# %%
# padding function from
# https://towardsdatascience.com/audio-deep-learning-made-simple-sound-classification-step-by-step-cebc936bbe5

X_full = [] # padded X values
y_full = []

numbers = [0] * 10

for file_path, audio in X_unfiltered:
    x_val = audio
    y_val = get_label(file_path)
    
    signal_length = audio.shape[0]
    if signal_length > max_length:
        numbers[y_val] += 1
    else:
        pad_len = max_length - signal_length
        
        x_val = np.pad(
            x_val, (0, pad_len), 
            'constant', constant_values=(0, 0))
        
        mel_x = mel_spec(x_val)
        
        X_full.append(mel_x)
        y_full.append(y_val)

X_full = np.array(X_full)
y_full = np.array(y_full)

num_samples, sample_w, sample_h = X_full.shape
print(num_samples)
print(sample_w, sample_h)
print(y_full[:10])
# Out:
# 2911
# 128 24
# [2 6 7 1 2 6 6 4 8 3]

# %%
# quantities = {"y": list(range(10)), "quantities": numbers}
df = pd.DataFrame.from_dict({"quantities": numbers})
print(df)
print(sum(numbers))
# Out:
#    quantities
# 0          11
# 1           8
# 2           6
# 3           5
# 4           3
# 5           6
# 6          23
# 7          11
# 8           6
# 9          10
# 89

# %%
mean = np.mean(X_full)
std = np.std(X_full)
X_full = X_full - mean
X_full = X_full / std

# %%
rows = 3
cols = 3
n = rows * cols
fig, axes = plt.subplots(rows, cols, figsize=(12, 14))

for i, (audio, label) in enumerate(list(zip(X_full, y_full))[:n]):
    r = i // cols
    c = i % cols
    ax = axes[r][c]
    
    librosa.display.specshow(audio, y_axis='mel', fmax=8000, x_axis='time', ax=axes[r][c]);
#     plt.title('Mel Spectrogram');
#     plt.colorbar(format='%+2.0f dB');
    
#     ax.plot(audio)
#     ax.set_yticks(np.arange(-1,1.5,0.5))
    ax.set_title(label)

plt.show()

# %%
tenth = int(num_samples * 0.1)
eightyth = tenth * 8

X_train = X_full[:eightyth]
y_train = y_full[:eightyth]

X_val = X_full[eightyth: eightyth + tenth]
y_val = y_full[eightyth: eightyth + tenth]

X_test = X_full[eightyth + tenth:]
y_test = y_full[eightyth + tenth:]

print('Training set size', len(X_train))
print('Validation set size', len(X_val))
print('Test set size', len(X_test))
# Out:
# Training set size 2328
# Validation set size 291
# Test set size 292

# %%
# UNUSED

class MyNormLayer(tf.keras.layers.Layer):
    def __init__(self, mean, std):
        super(MyNormLayer, self).__init__()
        self.mean = mean
        self.std = std
    
    def get_config(self):
        config = super().get_config()
        config.update({
            "mean": self.mean,
            "std": self.std,
        })
        return config

    def call(self, inputs):
        return (inputs - self.mean) / self.std

# %%
# INPUTS ARE NORMALIZED

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Input(shape=(sample_w, sample_h, 1)))
model.add(tf.keras.layers.Conv2D(32, 3, activation='relu'))
model.add(tf.keras.layers.Conv2D(64, 3, activation='relu'))
model.add(tf.keras.layers.MaxPooling2D())
model.add(tf.keras.layers.Dropout(0.25))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation="relu"))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(10, activation="softmax"))

model.build()
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_11 (Conv2D)          (None, 126, 22, 32)       320
#
#  conv2d_12 (Conv2D)          (None, 124, 20, 64)       18496
#
#  max_pooling2d_5 (MaxPooling  (None, 62, 10, 64)       0
#  2D)
#
#  dropout_10 (Dropout)        (None, 62, 10, 64)        0
#
#  flatten_5 (Flatten)         (None, 39680)             0
#
#  dense_10 (Dense)            (None, 128)               5079168
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_11 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 5,099,274
# Trainable params: 5,099,274
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="sparse_categorical_crossentropy",
             optimizer="adam",
             metrics=["accuracy"])

# %%
history = model.fit(X_train, y_train, epochs=30,
                   validation_data=(X_val, y_val))
# Out:
# Epoch 1/30
# 73/73 [==============================] - 8s 101ms/step - loss: 2.1552 - accuracy: 0.2526 - val_loss: 1.3851 - val_accuracy: 0.6460
# Epoch 2/30
# 73/73 [==============================] - 8s 108ms/step - loss: 1.3202 - accuracy: 0.5159 - val_loss: 0.7486 - val_accuracy: 0.7629
# Epoch 3/30
# 73/73 [==============================] - 8s 112ms/step - loss: 0.9714 - accuracy: 0.6426 - val_loss: 0.4277 - val_accuracy: 0.8969
# Epoch 4/30
# 73/73 [==============================] - 9s 123ms/step - loss: 0.7225 - accuracy: 0.7341 - val_loss: 0.2945 - val_accuracy: 0.9175
# Epoch 5/30
# 73/73 [==============================] - 8s 116ms/step - loss: 0.6890 - accuracy: 0.7448 - val_loss: 0.3473 - val_accuracy: 0.8969
# Epoch 6/30
# 73/73 [==============================] - 8s 112ms/step - loss: 0.5883 - accuracy: 0.7779 - val_loss: 0.2298 - val_accuracy: 0.9485
# Epoch 7/30
# 73/73 [==============================] - 9s 123ms/step - loss: 0.4901 - accuracy: 0.8200 - val_loss: 0.1760 - val_accuracy: 0.9485
# Epoch 8/30
# 73/73 [==============================] - 12s 170ms/step - loss: 0.4185 - accuracy: 0.8466 - val_loss: 0.1819 - val_accuracy: 0.9485
# Epoch 9/30
# 73/73 [==============================] - 15s 203ms/step - loss: 0.3894 - accuracy: 0.8574 - val_loss: 0.1675 - val_accuracy: 0.9588
# Epoch 10/30
# 73/73 [==============================] - 12s 161ms/step - loss: 0.3690 - accuracy: 0.8570 - val_loss: 0.1492 - val_accuracy: 0.9519
# Epoch 11/30
# 73/73 [==============================] - 11s 152ms/step - loss: 0.3312 - accuracy: 0.8746 - val_loss: 0.1202 - val_accuracy: 0.9588
# Epoch 12/30
# 73/73 [==============================] - 12s 163ms/step - loss: 0.3203 - accuracy: 0.8845 - val_loss: 0.0852 - val_accuracy: 0.9725
# Epoch 13/30
# 73/73 [==============================] - 11s 156ms/step - loss: 0.2832 - accuracy: 0.8896 - val_loss: 0.1053 - val_accuracy: 0.9622
# Epoch 14/30
# 73/73 [==============================] - 11s 152ms/step - loss: 0.3046 - accuracy: 0.8771 - val_loss: 0.1029 - val_accuracy: 0.9588
# Epoch 15/30
# 73/73 [==============================] - 11s 155ms/step - loss: 0.2629 - accuracy: 0.8896 - val_loss: 0.1435 - val_accuracy: 0.9759
# Epoch 16/30
# 73/73 [==============================] - 12s 159ms/step - loss: 0.2264 - accuracy: 0.9175 - val_loss: 0.1085 - val_accuracy: 0.9691
# Epoch 17/30
# 73/73 [==============================] - 11s 153ms/step - loss: 0.2190 - accuracy: 0.9141 - val_loss: 0.1321 - val_accuracy: 0.9588
# Epoch 18/30
# 73/73 [==============================] - 11s 153ms/step - loss: 0.2148 - accuracy: 0.9102 - val_loss: 0.1048 - val_accuracy: 0.9725
# Epoch 19/30
# 73/73 [==============================] - 11s 151ms/step - loss: 0.2060 - accuracy: 0.9197 - val_loss: 0.0948 - val_accuracy: 0.9725
# Epoch 20/30
# 73/73 [==============================] - 14s 189ms/step - loss: 0.2207 - accuracy: 0.9128 - val_loss: 0.1024 - val_accuracy: 0.9759
# Epoch 21/30
# 73/73 [==============================] - 15s 204ms/step - loss: 0.2158 - accuracy: 0.9107 - val_loss: 0.0922 - val_accuracy: 0.9759
# Epoch 22/30
# 73/73 [==============================] - 13s 176ms/step - loss: 0.1935 - accuracy: 0.9227 - val_loss: 0.0800 - val_accuracy: 0.9759
# Epoch 23/30
# 73/73 [==============================] - 13s 179ms/step - loss: 0.1914 - accuracy: 0.9244 - val_loss: 0.0961 - val_accuracy: 0.9725
# Epoch 24/30
# 73/73 [==============================] - 12s 164ms/step - loss: 0.2050 - accuracy: 0.9223 - val_loss: 0.0757 - val_accuracy: 0.9759
# Epoch 25/30
# 73/73 [==============================] - 12s 159ms/step - loss: 0.1741 - accuracy: 0.9291 - val_loss: 0.1018 - val_accuracy: 0.9656
# Epoch 26/30
# 73/73 [==============================] - 11s 151ms/step - loss: 0.1795 - accuracy: 0.9296 - val_loss: 0.0940 - val_accuracy: 0.9656
# Epoch 27/30
# 73/73 [==============================] - 10s 140ms/step - loss: 0.1603 - accuracy: 0.9347 - val_loss: 0.0830 - val_accuracy: 0.9863
# Epoch 28/30
# 73/73 [==============================] - 12s 157ms/step - loss: 0.1931 - accuracy: 0.9192 - val_loss: 0.0614 - val_accuracy: 0.9794
# Epoch 29/30
# 73/73 [==============================] - 12s 162ms/step - loss: 0.1710 - accuracy: 0.9338 - val_loss: 0.1000 - val_accuracy: 0.9691
# Epoch 30/30
# 73/73 [==============================] - 10s 141ms/step - loss: 0.1670 - accuracy: 0.9308 - val_loss: 0.1006 - val_accuracy: 0.9725

# %%
model.evaluate(X_test, y_test)
# Out:
# 10/10 [==============================] - 0s 24ms/step - loss: 0.1322 - accuracy: 0.9726
# [0.13217578828334808, 0.9726027250289917]

# %%
y_pred = np.argmax(model.predict(X_test), axis=1)

all_labels = list(range(10))

confusion_mtx = tf.math.confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_mtx,
            xticklabels=all_labels,
            yticklabels=all_labels,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %%
model.save("model_v3.h5")
