# %%
import random

# for data, model, training
import pandas as pd
import numpy as np
import tensorflow as tf
import librosa

import matplotlib.pyplot as plt
import seaborn as sns

import basics

# Set the seed value for experiment reproducibility.
seed = 42
random.seed(42)
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
filenames = basics.get_and_shuffle_filenames("./recordings")

print(filenames[:5])
# Out:
# ['./recordings/2_jackson_13.wav', './recordings/6_george_34.wav', './recordings/7_george_5.wav', './recordings/1_yweweler_21.wav', './recordings/2_george_42.wav']

# %%
X_unfiltered = [(file_path, basics.decode_audio(file_path)) for file_path in filenames]

# to remove outliers 
max_length = basics.get_max_length(X_unfiltered)
print(max_length)
# Out:
# 5632

# %%
def mel_spec(signal):
    mel_spect = librosa.feature.melspectrogram(y=signal, sr=8000, n_fft=248, hop_length=248)
    mel_spect = librosa.power_to_db(mel_spect, ref=np.max)
    return mel_spect

# %%
X_full = [] # padded X values
y_full = []

numbers = [0] * 10

for file_path, audio in X_unfiltered:
    x_val = audio
    y_val = basics.get_label(file_path)
    
    signal_length = audio.shape[0]
    if signal_length > max_length:
        numbers[y_val] += 1
        continue
        
    x_val = np.pad(
        x_val, (0, max_length - signal_length), 
        'constant', constant_values=(0, 0))

    mel_x = mel_spec(x_val)

    X_full.append(mel_x)
    y_full.append(y_val)

X_full = np.array(X_full)
y_full = np.array(y_full)

num_samples, sample_w, sample_h = X_full.shape
print(num_samples)
print(sample_w, sample_h)
# Out:
# 2896
# 128 23

# %%
# dropped outliers
df = pd.DataFrame.from_dict({"quantities": numbers})
print(df)
print(sum(numbers))
# Out:
#    quantities
# 0          12
# 1           9
# 2           7
# 3           9
# 4           3
# 5           8
# 6          29
# 7          11
# 8           6
# 9          10
# 104

# %%
rows = 3
cols = 3
n = rows * cols
fig, axes = plt.subplots(rows, cols, figsize=(12, 14))

for i, (audio, label) in enumerate(list(zip(X_full, y_full))[:n]):
    r = i // cols
    c = i % cols
    ax = axes[r][c]
    
    librosa.display.specshow(audio, y_axis='mel', fmax=8000, x_axis='time', ax=axes[r][c]);
    ax.set_title(label)

plt.show()

# %%
# normalize data
X_full = basics.normalize_arr(X_full)

# partition into 80:10:10
partitions = basics.split_full(X_full, y_full)

X_train, y_train = partitions[0]
X_val, y_val = partitions[1]
X_test, y_test = partitions[2]

print('Training set size', len(X_train))
print('Validation set size', len(X_val))
print('Test set size', len(X_test))
# Out:
# Training set size 2312
# Validation set size 289
# Test set size 295

# %%
# UNUSED

class MyNormLayer(tf.keras.layers.Layer):
    def __init__(self, mean, std):
        super(MyNormLayer, self).__init__()
        self.mean = mean
        self.std = std
    
    def get_config(self):
        config = super().get_config()
        config.update({
            "mean": self.mean,
            "std": self.std,
        })
        return config

    def call(self, inputs):
        return (inputs - self.mean) / self.std

# %%
# INPUTS ARE NORMALIZED

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Input(shape=(sample_w, sample_h, 1)))
model.add(tf.keras.layers.Conv2D(32, 3, activation='relu'))
model.add(tf.keras.layers.Conv2D(64, 3, activation='relu'))
model.add(tf.keras.layers.MaxPooling2D())
model.add(tf.keras.layers.Dropout(0.25))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation="relu"))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(10, activation="softmax"))

model.build()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 21, 32)       320
#
#  conv2d_1 (Conv2D)           (None, 124, 19, 64)       18496
#
#  max_pooling2d (MaxPooling2D  (None, 62, 9, 64)        0
#  )
#
#  dropout (Dropout)           (None, 62, 9, 64)         0
#
#  flatten (Flatten)           (None, 35712)             0
#
#  dense (Dense)               (None, 128)               4571264
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 4,591,370
# Trainable params: 4,591,370
# Non-trainable params: 0
# _________________________________________________________________
# 2022-05-07 18:16:32.981344: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.compile(loss="sparse_categorical_crossentropy",
             optimizer="adam",
             metrics=["accuracy"])

# %%
history = model.fit(X_train, y_train, epochs=30,
                   validation_data=(X_val, y_val))
# Out:
# Epoch 1/30
# 73/73 [==============================] - 9s 111ms/step - loss: 1.9420 - accuracy: 0.2993 - val_loss: 1.0116 - val_accuracy: 0.7370
# Epoch 2/30
# 73/73 [==============================] - 8s 103ms/step - loss: 1.0242 - accuracy: 0.6380 - val_loss: 0.4654 - val_accuracy: 0.8789
# Epoch 3/30
# 73/73 [==============================] - 8s 109ms/step - loss: 0.7115 - accuracy: 0.7491 - val_loss: 0.2648 - val_accuracy: 0.9308
# Epoch 4/30
# 73/73 [==============================] - 8s 103ms/step - loss: 0.5666 - accuracy: 0.8049 - val_loss: 0.2138 - val_accuracy: 0.9308
# Epoch 5/30
# 73/73 [==============================] - 8s 104ms/step - loss: 0.3970 - accuracy: 0.8521 - val_loss: 0.1867 - val_accuracy: 0.9377
# Epoch 6/30
# 73/73 [==============================] - 8s 108ms/step - loss: 0.3716 - accuracy: 0.8655 - val_loss: 0.1182 - val_accuracy: 0.9689
# Epoch 7/30
# 73/73 [==============================] - 8s 110ms/step - loss: 0.3072 - accuracy: 0.8880 - val_loss: 0.1464 - val_accuracy: 0.9516
# Epoch 8/30
# 73/73 [==============================] - 8s 115ms/step - loss: 0.2761 - accuracy: 0.8997 - val_loss: 0.1077 - val_accuracy: 0.9723
# Epoch 9/30
# 73/73 [==============================] - 8s 103ms/step - loss: 0.2363 - accuracy: 0.9113 - val_loss: 0.1020 - val_accuracy: 0.9689
# Epoch 10/30
# 73/73 [==============================] - 8s 112ms/step - loss: 0.2469 - accuracy: 0.9053 - val_loss: 0.0970 - val_accuracy: 0.9689
# Epoch 11/30
# 73/73 [==============================] - 8s 105ms/step - loss: 0.1797 - accuracy: 0.9373 - val_loss: 0.0750 - val_accuracy: 0.9792
# Epoch 12/30
# 73/73 [==============================] - 7s 102ms/step - loss: 0.1985 - accuracy: 0.9260 - val_loss: 0.0908 - val_accuracy: 0.9654
# Epoch 13/30
# 73/73 [==============================] - 8s 108ms/step - loss: 0.1577 - accuracy: 0.9459 - val_loss: 0.0687 - val_accuracy: 0.9758
# Epoch 14/30
# 73/73 [==============================] - 8s 103ms/step - loss: 0.1669 - accuracy: 0.9420 - val_loss: 0.1427 - val_accuracy: 0.9654
# Epoch 15/30
# 73/73 [==============================] - 7s 102ms/step - loss: 0.1761 - accuracy: 0.9407 - val_loss: 0.1058 - val_accuracy: 0.9723
# Epoch 16/30
# 73/73 [==============================] - 7s 102ms/step - loss: 0.1556 - accuracy: 0.9420 - val_loss: 0.0959 - val_accuracy: 0.9758
# Epoch 17/30
# 73/73 [==============================] - 8s 104ms/step - loss: 0.1395 - accuracy: 0.9511 - val_loss: 0.1130 - val_accuracy: 0.9758
# Epoch 18/30
# 73/73 [==============================] - 8s 104ms/step - loss: 0.1224 - accuracy: 0.9537 - val_loss: 0.0756 - val_accuracy: 0.9792
# Epoch 19/30
# 73/73 [==============================] - 7s 102ms/step - loss: 0.1131 - accuracy: 0.9615 - val_loss: 0.1048 - val_accuracy: 0.9792
# Epoch 20/30
# 73/73 [==============================] - 8s 105ms/step - loss: 0.1138 - accuracy: 0.9602 - val_loss: 0.1424 - val_accuracy: 0.9654
# Epoch 21/30
# 73/73 [==============================] - 9s 124ms/step - loss: 0.1234 - accuracy: 0.9524 - val_loss: 0.1317 - val_accuracy: 0.9723
# Epoch 22/30
# 73/73 [==============================] - 8s 113ms/step - loss: 0.1167 - accuracy: 0.9567 - val_loss: 0.0793 - val_accuracy: 0.9689
# Epoch 23/30
# 73/73 [==============================] - 7s 101ms/step - loss: 0.1042 - accuracy: 0.9602 - val_loss: 0.1023 - val_accuracy: 0.9689
# Epoch 24/30
# 73/73 [==============================] - 8s 113ms/step - loss: 0.1128 - accuracy: 0.9593 - val_loss: 0.1224 - val_accuracy: 0.9723
# Epoch 25/30
# 73/73 [==============================] - 8s 113ms/step - loss: 0.0814 - accuracy: 0.9680 - val_loss: 0.1044 - val_accuracy: 0.9758
# Epoch 26/30
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0795 - accuracy: 0.9693 - val_loss: 0.1763 - val_accuracy: 0.9654
# Epoch 27/30
# 73/73 [==============================] - 9s 119ms/step - loss: 0.1055 - accuracy: 0.9624 - val_loss: 0.1026 - val_accuracy: 0.9723
# Epoch 28/30
# 73/73 [==============================] - 9s 118ms/step - loss: 0.0868 - accuracy: 0.9702 - val_loss: 0.1417 - val_accuracy: 0.9619
# Epoch 29/30
# 73/73 [==============================] - 8s 104ms/step - loss: 0.0880 - accuracy: 0.9637 - val_loss: 0.1377 - val_accuracy: 0.9723
# Epoch 30/30
# 73/73 [==============================] - 7s 99ms/step - loss: 0.0841 - accuracy: 0.9671 - val_loss: 0.0886 - val_accuracy: 0.9689

# %%
model.evaluate(X_test, y_test)
# Out:
# 10/10 [==============================] - 0s 26ms/step - loss: 0.1385 - accuracy: 0.9695
# [0.13850241899490356, 0.9694915413856506]

# %%
y_pred = np.argmax(model.predict(X_test), axis=1)

all_labels = list(range(10))

confusion_mtx = tf.math.confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_mtx,
            xticklabels=all_labels,
            yticklabels=all_labels,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()

# %%
model.save("model_v3.h5")
